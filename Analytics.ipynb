# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sentiments.csv")

# %%
print(df.head(10))
# Out:
#    Unnamed: 0                                             tweets  \
# 0           0  Interacted with heads of our Missions abroad o...
# 1           1  Representatives from social organisations spok...
# 2           2  Social organisations are embodiments of compas...
# 3           3  In our country, social organisations have a ve...
# 4           4  Condolences to you and the entire family, @Oma...
# 5           5  राजस्थान दिवस की वहां के सभी भाइयों और बहनों क...
# 6           6  The Yoga videos are available in different lan...
# 7           7  I am neither a fitness expert nor a medical ex...
# 8           8  During yesterday’s #MannKiBaat, someone asked ...
# 9           9  India will always remember the impeccable serv...
#
#                     id  len                 date              source   likes  \
# 0  1244656090404360192  139  2020-03-30 16:01:51  Twitter for iPhone   23071
# 1  1244616459382173702  140  2020-03-30 13:24:22     Twitter Web App   10000
# 2  1244616456504872960  140  2020-03-30 13:24:21     Twitter Web App   11288
# 3  1244616453896077312  140  2020-03-30 13:24:21     Twitter Web App   32015
# 4  1244491530611470336  139  2020-03-30 05:07:57  Twitter for iPhone   36661
# 5  1244491316060229632  140  2020-03-30 05:07:05  Twitter for iPhone  116827
# 6  1244456357647933440  121  2020-03-30 02:48:11  Twitter for iPhone   15056
# 7  1244456353956945921  140  2020-03-30 02:48:10  Twitter for iPhone   27151
# 8  1244456351180316672  140  2020-03-30 02:48:09  Twitter for iPhone   42481
# 9  1244290006299987968  140  2020-03-29 15:47:09  Twitter for iPhone  102364
#
#    retweets  sentiment
# 0      3536          1
# 1      1747          1
# 2      1863          1
# 3      4772          1
# 4      3808         -1
# 5     13364          0
# 6      2839          1
# 7      3893          1
# 8      7199          0
# 9     11541          1

# %%
#for checking the avg length of a tweet
print(np.mean(df['len']))
# Out:
# 131.275

# %%
#maximum number 
print(np.max(df['likes']))
# Out:
# 269950

# %%
print(np.max(df['retweets']))
# Out:
# 71497

# %%
#time series of likes
time_likes=pd.Series(data=df['likes'].values,index=df['date'])
time_likes.plot(figsize=(16,4),color='r')
plt.show()

# %%
#time series of retweets
time_retweets=pd.Series(data=df['retweets'].values,index=df['date'])
time_retweets.plot(figsize=(16,4),color='r')
plt.show()

# %%
#time series of retweets
time_retweets=pd.Series(data=df['retweets'].values,index=df['date'])
time_retweets.plot(figsize=(32,32),label='likes',legend=True)
plt.show()
